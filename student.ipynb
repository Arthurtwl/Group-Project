# %%
library(tidyverse)
library(repr)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.3.2     ✔ purrr   0.3.4
# ✔ tibble  3.0.3     ✔ dplyr   1.0.2
# ✔ tidyr   1.1.2     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.5.0
#
# Warning message:
# “package ‘ggplot2’ was built under R version 4.0.1”
# Warning message:
# “package ‘tibble’ was built under R version 4.0.2”
# Warning message:
# “package ‘tidyr’ was built under R version 4.0.2”
# Warning message:
# “package ‘dplyr’ was built under R version 4.0.2”
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
student=read_delim(file="data/student-mat.csv", delim=";")%>%
select(famsup, paid, activities, higher, studytime, famrel, freetime, health)
student
# Out:
# Parsed with column specification:
# cols(
#   .default = col_character(),
#   age = col_double(),
#   Medu = col_double(),
#   Fedu = col_double(),
#   traveltime = col_double(),
#   studytime = col_double(),
#   failures = col_double(),
#   famrel = col_double(),
#   freetime = col_double(),
#   goout = col_double(),
#   Dalc = col_double(),
#   Walc = col_double(),
#   health = col_double(),
#   absences = col_double(),
#   G1 = col_double(),
#   G2 = col_double(),
#   G3 = col_double()
# )
#
# See spec(...) for full column specifications.
#     famsup paid activities higher studytime famrel freetime health
# 1   no     no   no         yes    2         4      3        3
# 2   yes    no   no         yes    2         5      3        3
# 3   no     yes  no         yes    2         4      3        3
# 4   yes    yes  yes        yes    3         3      2        5
# 5   yes    yes  no         yes    2         4      3        5
# ...
